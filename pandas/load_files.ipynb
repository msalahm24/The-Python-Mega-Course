# %%
import os
os.listdir()
# Out:
# ['load_files.ipynb',
#  'app1',
#  'app1_with_db',
#  '5.2 supermarkets.csv.csv',
#  'venv',
#  '.ipynb_checkpoints',
#  '5.5 supermarkets-semi-colons.txt.txt',
#  '5.4 supermarkets-commas.txt.txt',
#  '5.3 supermarkets.json.json',
#  'files',
#  '5.1 supermarkets.xlsx.xlsx',
#  'core of python',
#  '.idea']

# %%
import pandas as pd

# %%
dfcsv=pd.read_csv('5.2 supermarkets.csv.csv')

# %%
dfjson=pd.read_json('5.3 supermarkets.json.json')

# %%
dfcsv
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
dfjson
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
dftxt=pd.read_csv('5.4 supermarkets-commas.txt.txt')

# %%
dftxt
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
dftxt=pd.read_csv('5.5 supermarkets-semi-colons.txt.txt',sep=';')

# %%
dftxt
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
dfxlsx=pd.read_excel('5.1 supermarkets.xlsx.xlsx',sheet_name=0)

# %%
dfxlsx.columns
# Out:
# Index(['ID', 'Address', 'City', 'State', 'Country', 'Supermarket Name',
#        'Number of Employees'],
#       dtype='object')

# %%
dfcsv.set_index('ID',inplace=True,drop=False)

# %%
dfcsv.loc[3:5,'City':'Name']
# Out:
#              City             State Country         Name
# ID
# 3   San Francisco  California 94114     USA  Super River
# 4   San Francisco          CA 94114     USA   Ben's Shop
# 5   San Francisco        California     USA      Sanchez

# %%
dftxt
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df.loc[0:1,'City':'Name']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-69-add4c0ef2f58> in <module>
# ----> 1 df.loc[0:1,'City':'Name']
#
# NameError: name 'df' is not defined

# %%
dfcsv.loc[:,'Employees']
# Out:
# ID
# 1     8
# 2    15
# 3    25
# 4    10
# 5    12
# 6    20
# Name: Employees, dtype: int64

# %%
dfcsv.drop('State',1,inplace=True)

# %%
dfcsv.drop(3,0,inplace=True)

# %%
dfcsv.drop(dfcsv.index[0:2],0)
# Out:
#     ID          Address           City Country        Name  Employees
# ID
# 4    4     3995 23rd St  San Francisco     USA  Ben's Shop         10
# 5    5  1056 Sanchez St  San Francisco     USA     Sanchez         12
# 6    6  551 Alvarado St  San Francisco     USA  Richvalley         20

# %%
dfcsv.shape
# Out:
# (5, 6)

# %%
dfcsv['contenet']=dfcsv.shape[0]*['mahmoud']

# %%
dfcsv.columns
# Out:
# Index(['ID', 'Address', 'City', 'Country', 'Name', 'Employees', 'contenet'], dtype='object')

# %%
dfcsv['contenet']=dfcsv['Country']+' , '+dfcsv['City']

# %%
dfcsv
# Out:
#     ID          Address           City Country         Name  Employees  \
# ID
# 1    1     3666 21st St  San Francisco     USA      Madeira          8
# 2    2   735 Dolores St  San Francisco     USA  Bready Shop         15
# 4    4     3995 23rd St  San Francisco     USA   Ben's Shop         10
# 5    5  1056 Sanchez St  San Francisco     USA      Sanchez         12
# 6    6  551 Alvarado St  San Francisco     USA   Richvalley         20
#
#                contenet
# ID
# 1   USA , San Francisco
# 2   USA , San Francisco
# 4   USA , San Francisco
# 5   USA , San Francisco
# 6   USA , San Francisco

# %%
dfcsv_t=dfcsv.T

# %%
dfcsv_t
# Out:
# ID                           1                    2                    4  \
# ID                           1                    2                    4
# Address           3666 21st St       735 Dolores St         3995 23rd St
# City             San Francisco        San Francisco        San Francisco
# Country                    USA                  USA                  USA
# Name                   Madeira          Bready Shop           Ben's Shop
# Employees                    8                   15                   10
# contenet   USA , San Francisco  USA , San Francisco  USA , San Francisco
#
# ID                           5                    6
# ID                           5                    6
# Address        1056 Sanchez St      551 Alvarado St
# City             San Francisco        San Francisco
# Country                    USA                  USA
# Name                   Sanchez           Richvalley
# Employees                   12                   20
# ...

# %%
dfcsv_t[7]=[7,'my add','my city','my country','my name',9,'USA , San']

# %%
dfcsv_t
# Out:
# ID                           1                    2                    4  \
# ID                           1                    2                    4
# Address           3666 21st St       735 Dolores St         3995 23rd St
# City             San Francisco        San Francisco        San Francisco
# Country                    USA                  USA                  USA
# Name                   Madeira          Bready Shop           Ben's Shop
# Employees                    8                   15                   10
# contenet   USA , San Francisco  USA , San Francisco  USA , San Francisco
#
# ID                           5                    6           7
# ID                           5                    6           7
# Address        1056 Sanchez St      551 Alvarado St      my add
# City             San Francisco        San Francisco     my city
# Country                    USA                  USA  my country
# ...

# %%
dfcsv=dfcsv_t.T

# %%
import geopy
dfcsv
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
dir(geopy)
# Out:
# ['AlgoliaPlaces',
#  'ArcGIS',
#  'AzureMaps',
#  'BANFrance',
#  'Baidu',
#  'BaiduV3',
#  'Bing',
#  'DataBC',
#  'GeoNames',
#  'GeocodeEarth',
#  'GeocodeFarm',
#  'Geolake',
#  'GoogleV3',
#  'Here',
#  'IGNFrance',
#  'LiveAddress',
#  'Location',
#  'MapBox',
#  'MapQuest',
#  'MapTiler',
#  'Nominatim',
#  'OpenCage',
#  'OpenMapQuest',
#  'Pelias',
#  'Photon',
#  'PickPoint',
#  'Point',
#  'Timezone',
#  'TomTom',
#  'What3Words',
#  'Yandex',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'compat',
#  'exc',
#  'format',
#  'geocoders',
#  'get_geocoder_for_service',
#  'location',
#  'point',
#  'timezone',
#  'units',
#  'util']

# %%
from geopy.geocoders import ArcGIS as AG

# %%
nom=AG(timeout=5)

# %%
n=nom.geocode('3995 23rd , San Francisco, CA 94114')

# %%
print(n)
# Out:
# 3995 23rd St, San Francisco, California, 94114

# %%
n.latitude
# Out:
# 37.752990821253434

# %%
n.longitude
# Out:
# -122.43170235858965

# %%
dfcsv
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
dfcsv['GeoAddress']=dfcsv['Address'] +', '+dfcsv['City']+', '+dfcsv['State']+', '+dfcsv['Country']

# %%
dfcsv
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees                                         GeoAddress
# 0          8         3666 21st St, San Francisco, CA 94114, USA
# 1         15       735 Dolores St, San Francisco, CA 94119, USA
# 2         25  332 Hill St, San Francisco, California 94114, USA
# 3         10         3995 23rd St, San Francisco, CA 94114, USA
# 4         12    1056 Sanchez St, San Francisco, California, USA
# ...

# %%
dfcsv['coordinates']=dfcsv['GeoAddress'].apply(nom.geocode)

# %%
dfcsv['latitude']=dfcsv['coordinates'].apply(lambda x:x.latitude if x != None else None)

# %%
dfcsv
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees                                         GeoAddress  \
# 0          8         3666 21st St, San Francisco, CA 94114, USA
# 1         15       735 Dolores St, San Francisco, CA 94119, USA
# 2         25  332 Hill St, San Francisco, California 94114, USA
# 3         10         3995 23rd St, San Francisco, CA 94114, USA
# 4         12    1056 Sanchez St, San Francisco, California, USA
# ...

# %%
dfcsv['longitude']=dfcsv['coordinates'].apply(lambda x:x.longitude if x != None else None)
